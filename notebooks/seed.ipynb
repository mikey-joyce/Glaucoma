# %%
import pandas as pd

df = pd.read_excel('../data/seed/SEED.xlsx')
df
# Out:
#            sno  time_between_visits  gender        age     bpsys_f  bpdia_f  \
# 0      MS26151                  NaN       2  65.086927  162.500000     68.0
# 1      MS21290                  NaN       2  43.819302  132.500000     84.5
# 2      MS11063                  NaN       2  66.313484  144.500000     70.0
# 3      MS26049             5.648186       1  43.241615  144.000000     85.5
# 4      MS13148                  NaN       1  77.075975  118.000000     63.5
# ...        ...                  ...     ...        ...         ...      ...
# 10028  CS51759             3.181383       1  48.531143  155.500000     89.5
# 10029  CS50489                  NaN       1  55.504449  145.000000     89.5
# 10030  CS55300             6.428474       1  61.393566  122.500000     80.0
# 10031  CS51844             5.571526       2  55.857632  138.666667     84.0
# 10032  CS59766             4.955510       2  46.828200  129.500000     65.5
#
# ...

# %%
unique_subjects = df['sno'].nunique()
print(f"Number of unique subjects: {unique_subjects}")
# Out:
# Number of unique subjects: 10033
